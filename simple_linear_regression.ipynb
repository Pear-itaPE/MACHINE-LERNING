# %%
import numpy as np 
import matplotlib.pyplot as plt 
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression  
from sklearn.metrics import classification_report, accuracy_score

# %%
sp= pd.read_csv("Salary_Data.csv")

# %%
#Definir x/y
x = sp.iloc[:, :-1].values
y= sp.iloc[:, 1].values

# %%
#Dividir el data set en conjunto de entrenamiento y conjunto de testing
x_train, x_test, y_train, y_test = train_test_split( x,y, test_size=1/3, random_state=0)

# %%
# Modelo de regresion lineal simple con datos de entrenamiento
regression= LinearRegression()
regression.fit(x_train,y_train) # Deben tener el mismo numero de filas
# Out:
# LinearRegression()

# %%
# Predecir el conujnto de test
y_pred= regression.predict(x_test) # Variables independientes

# %%
# Visualizar los resultados de entrenamiento

# %%
plt.scatter(x_train,y_train, color="red")
plt.plot(x_train,regression.predict(x_train),color="blue")
plt.title("Sueldo vs Años de Experiencia (Conjunto de entrenamiento)")
plt.xlabel('Años de experiencia')
plt.ylabel("Sueldo (en $)")
# Out:
# Text(0, 0.5, 'Sueldo (en $)')

# %%
# Visualizar los resultados de test
plt.scatter(x_test,y_test, color="red")
plt.plot(x_train,regression.predict(x_train),color="blue") #Linea de regresión es la misma
plt.title("Sueldo vs Años de Experiencia (Conjunto de testing)")
plt.xlabel('Años de experiencia')
plt.ylabel("Sueldo (en $)")
# Out:
# Text(0, 0.5, 'Sueldo (en $)')
